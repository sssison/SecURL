# %%
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
dataset = pd.read_csv('final_unbalanced_with_lexical.csv')
dataset.head()
# Out:
#    url_type  url_length  url_ip_in_domain  url_domain_entropy  \
# 0         2          16                 0            3.169925
# 1         0          35                 0            2.807355
# 2         0          31                 0            2.921928
# 3         1          88                 0            2.896292
# 4         1         235                 0            3.405822
#
#    url_is_digits_in_domain  url_query_length  url_number_of_parameters  \
# 0                        0                 0                         0
# 1                        1                 0                         0
# 2                        0                 0                         0
# 3                        0                49                         4
# 4                        0               194                         3
#
#    url_number_of_digits  url_string_entropy  url_is_https  ...  \
# 0                     0            3.375000             0  ...
# ...

# %%
features = dataset.iloc[:, 1:]
url_type = dataset.iloc[:, 0]

# %%
features.head()
# Out:
#    url_length  url_ip_in_domain  url_domain_entropy  url_is_digits_in_domain  \
# 0          16                 0            3.169925                        0
# 1          35                 0            2.807355                        1
# 2          31                 0            2.921928                        0
# 3          88                 0            2.896292                        0
# 4         235                 0            3.405822                        0
#
#    url_query_length  url_number_of_parameters  url_number_of_digits  \
# 0                 0                         0                     0
# 1                 0                         0                     1
# 2                 0                         0                     1
# 3                49                         4                     7
# 4               194                         3                    22
#
#    url_string_entropy  url_is_https  url_path_length  ...  has_swf_in_string  \
# ...

# %%
url_type.head()
# Out:
# 0    2
# 1    0
# 2    0
# 3    1
# 4    1
# Name: url_type, dtype: int64

# %%
features_train, features_test, url_type_train, url_type_test = train_test_split(features, url_type, test_size = 0.3)

# %%
forward_feature_selection = SequentialFeatureSelector(XGBClassifier(), k_features = 76, forward = True,
                                                      floating = False, verbose = 2, scoring = 'accuracy', cv = 5).fit(features_train, url_type_train)
# Out:
# [Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 30.4min
#
# [2024-03-03 19:26:40] Features: 1/76 -- score: 0.7768929310578263[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 31.7min
#
# [2024-03-03 20:24:47] Features: 2/76 -- score: 0.8284122605567121[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 39.5min
#
# [2024-03-03 21:18:36] Features: 3/76 -- score: 0.872550513509031[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 29.5min
#
# [2024-03-03 22:21:24] Features: 4/76 -- score: 0.9002603744227866[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 39.9min
#
# [2024-03-03 23:31:46] Features: 5/76 -- score: 0.9173151618658514[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 54.4min
#
# [2024-03-04 01:08:01] Features: 6/76 -- score: 0.9311586079102241[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 27.8min
#
# [2024-03-04 01:53:29] Features: 7/76 -- score: 0.9355977004606743[Parallel(n_jobs=1)]: Done  40 tasks      | elapsed: 24.4min
#
# ...

# %%
forward_feature_selection.k_feature_names_
# Out:
# ('url_length',
#  'url_ip_in_domain',
#  'url_domain_entropy',
#  'url_is_digits_in_domain',
#  'url_query_length',
#  'url_number_of_parameters',
#  'url_number_of_digits',
#  'url_string_entropy',
#  'url_is_https',
#  'url_path_length',
#  'url_host_length',
#  'url_number_of_subdirectories',
#  'get_tld',
#  'url_domain_len',
#  'url_num_subdomain',
#  'url_has_port',
#  'url_number_of_fragments',
#  'url_is_encoded',
#  'url_number_of_letters',
#  'url_num_periods',
#  'url_num_of_hyphens',
#  'url_num_underscore',
#  'url_num_equal',
#  'url_num_forward_slash',
#  'url_num_question_mark',
#  'url_num_semicolon',
#  'url_num_open_parenthesis',
#  'url_num_close_parenthesis',
#  'url_num_mod_sign',
#  'url_num_ampersand',
#  'url_num_at',
#  'has_secure_in_string',
#  'has_account_in_string',
#  'has_webscr_in_string',
#  'has_login_in_string',
#  'has_ebayisapi_in_string',
#  'has_signin_in_string',
#  'has_banking_in_string',
#  'has_confirm_in_string',
# ...
